# %%
import pandas as pd
import numpy as np
import sqlite3
# %matplotlib inline

# %%
# read in the data
qcourse_df = pd.read_csv('qcourses.csv')
course_df = pd.read_csv('courses.csv', escapechar="\\")
dept_df = pd.read_csv('departments.csv')

# %%
# convert workload and overall ratings to numeric
qcourse_df = (qcourse_df.drop(['Workload', 'CourseOverall'], axis=1)
              .join(qcourse_df[['Workload', 'CourseOverall']].apply(pd.to_numeric, errors='coerce')))

# %%
pd.to_numeric(qcourse_df['ResponseRate'], errors='coerce').dropna().mean()
# Out:
# 79.41169244409417

# %%
# drop courses with no values for Workload or CourseOverall
qcourse_df = qcourse_df[~pd.isnull(qcourse_df['Workload'])]
qcourse_df = qcourse_df[~pd.isnull(qcourse_df['CourseOverall'])]
# drop courses without catalogue numbers
qcourse_df = qcourse_df[~pd.isnull(qcourse_df['cat_num'])]
course_df = course_df[~pd.isnull(course_df['cat_num'])]

# %%
qcourse_df['cat_num'] = qcourse_df['cat_num'].astype(int)
course_df['cat_num'] = course_df['cat_num'].astype(int)

# %%
dept_df['department_id'] = dept_df['id']
dept_df['dept_name'] = dept_df['short_name']
dept_df['department_id'] = dept_df['department_id'].astype(int)

# %%
# get department and course names
df = qcourse_df[['course_id', 'Workload', 'CourseOverall', 'Evaluations', 'cat_num', 'year']]\
        .merge(course_df[['cat_num', 'title', 'department_id', 'fall']], on='cat_num', how='left')\
        .merge(dept_df[['department_id', 'dept_name']], on='department_id', how='left')

# %%
# filter from fall 2014 onward
df = df[(df['year'] > 2014) | ((df['year'] == 2014) & (df['fall'] == 'Y'))]

# %%
df[(df['year'] == 2016) & (df['fall'] == 'Y')]
# Out:
#        course_id  Workload  CourseOverall Evaluations  cat_num  year  \
# 18889         80       2.6            4.6          58   123435  2016
# 18895          6       5.0            5.0           2   118965  2016
# 18896          7       3.2            4.8          13   126300  2016
# 18897      10628       2.0            5.0          10   109427  2016
# 18898      11510       2.3            4.0           3   110410  2016
# 18899      12857       2.9            4.7          14   156750  2016
# 18900      14699       3.5            4.5           2   204110  2016
# 18901         12       4.7            4.5           6   126306  2016
# 18902         14       3.2            3.9           8   126308  2016
# 18903         15       3.0            5.0           1   126309  2016
# 18904      11417       3.8            3.5           4   126313  2016
# 18905         18       2.0            3.0           1   126314  2016
# 18906         20       2.6            4.5          36   126316  2016
# 18907         23       2.7            4.6           5   127929  2016
# 18908       5268       6.0            5.0           1   109290  2016
# 18913        130       2.7            4.2          42   113901  2016
# 19022       5013      10.0            4.0           4   117068  2016
# 19023       5002      11.1            4.4           8   135062  2016
# 19024       5015       6.0            4.7           6   108587  2016
# 19041      13103       9.3            3.5         135   160409  2016
# 19051       1262       4.8            4.6           7   120237  2016
# 19061        765       6.0            4.5          28   112053  2016
# 19070      13962       5.1            4.9           9   161272  2016
# 19083        846       9.9            4.5          17   118533  2016
# 19109        930       5.2            3.3         491   113326  2016
# 19114        996       5.0            4.4          25   116133  2016
# 19126       1035      11.8            3.3          45   115026  2016
# 19140       1078       4.7            4.7           7   110731  2016
# 19149      10717       4.8            4.3          12   126659  2016
# 19162       1339      10.9            3.0          21   143433  2016
# ...          ...       ...            ...         ...      ...   ...
# 19542       2854       9.1            4.0           7   111065  2016
# 19559       2885      12.8            4.7           4   123242  2016
# 19608       3462       1.0            3.0           4   109015  2016
# 19662       3666       9.3            4.7           3   118078  2016
# 19863  Advanced Italian I: Oral Expression and Perfor...           127    Y
# 19869                     Intensive Beginning Portuguese           129    Y
# 19889            The Ethics of Business in Latin America           132    Y
# 19920                Crime and Security in Latin America           136    Y
# 19931                                 Economic Sociology           137    Y
# 19936                     Refugees in Global Perspective           137    Y
# 19939                   Organizational Analysis: Seminar           137    Y
# 19980                                      Linear Models           147    Y
# 20009  What's so Funny?: Introduction to Improvisatio...           499    Y
# 20014                     GAGA People: Movement Language           499    Y
# 20018                            Acting and Authenticity           499    Y
# 20024  Principles and Plasticity: Intermediate Painti...           162    Y
# 20050            Introduction to Non Fiction Videomaking           162    Y
# 20060  "Who Run the World?" Feminism in the Age of Em...           149    Y
#
#                                       dept_name
# 18889      African and African American Studies
# 18895      African and African American Studies
# 18896                                   AMHARIC
# 18897                                  AFRIKAAN
# 18898      African and African American Studies
# 18899                                  JAMAICAN
# 18900                                  WSTAFRCN
# 18901                                   HAITIAN
# 18902                                      IGBO
# 18903      African and African American Studies
# 18904                                  TIGRINYA
# 18905      African and African American Studies
# 18906                                      ZULU
# 18907                                  SUDANESE
# 18908      African and African American Studies
# 18913                              Anthropology
# 19022                              The Classics
# 19023                              The Classics
# 19024                              The Classics
# 19041          Engineering and Applied Sciences
# 19051          Engineering and Applied Sciences
# 19061    East Asian Languages and Civilizations
# 19070    East Asian Languages and Civilizations
# 19083    East Asian Languages and Civilizations
# 19109                                 Economics
# 19114                                 Economics
# 19126                                 Economics
# 19140                                 Economics
# 19149                                 Economics
# 19162          Engineering and Applied Sciences
# ...                                         ...
# 19542                               Mathematics
# 19559                               Mathematics
# 19608                          Medical Sciences
# 19662                                     Music
# 19664                                     Music
# 19689  Near Eastern Languages and Civilizations
# 19702       Organismic and Evolutionary Biology
# 19714       Organismic and Evolutionary Biology
# 19734                                Philosophy
# 19735                                Philosophy
# 19752                                   Physics
# 19783                                Psychology
# 19813                                Psychology
# 19823                     The Study of Religion
# 19852         Romance Languages and Literatures
# 19858         Romance Languages and Literatures
# 19863         Romance Languages and Literatures
# 19869         Romance Languages and Literatures
# 19889         Romance Languages and Literatures
# 19920                            Social Studies
# 19931                                 Sociology
# 19936                                 Sociology
# 19939                                 Sociology
# 19980                                Statistics
# 20009                    Theater, Dance & Media
# 20014                    Theater, Dance & Media
# 20018                    Theater, Dance & Media
# 20024          Visual and Environmental Studies
# 20050          Visual and Environmental Studies
# 20060   Studies of Women, Gender, and Sexuality
#
# [80 rows x 10 columns]

# %%
df.shape
# Out:
# (4765, 10)

# %%
df['CourseOverall'].corr(df['Workload'])
# Out:
# 0.011770822214090787

# %%
dept_count_df = df.groupby('dept_name')['CourseOverall'].count().reset_index().sort_values(by='CourseOverall', ascending=False)

# %%
most_popular_departments = dept_count_df.iloc[:10,:]['dept_name']

# %%
pop_dept_corrs = df[df['dept_name'].isin(most_popular_departments)].groupby('dept_name')[['CourseOverall', 'Workload']].corr().ix[0::2,'Workload'].reset_index()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
pop_dept_counts = df[df['dept_name'].isin(most_popular_departments)].groupby('dept_name').count()['course_id'].reset_index()

# %%
pop_dept_df = pop_dept_corrs.merge(pop_dept_counts, on='dept_name')[['dept_name', 'Workload', 'course_id']]

# %%
pop_dept_df.rename({'dept_name': 'Department Name', 'Workload': 'Correlation Value', 'course_id': 'Sample Size'},
                   axis='columns').to_csv('correlation_by_department.csv', index=False)
